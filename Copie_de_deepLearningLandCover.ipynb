# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushclin/iac-compettion/blob/main/Copie_de_deepLearningLandCover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install some packages
# !pip install rasterio
# !pip install earthpy
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.26.4)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 20.1 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.4.3
# Collecting earthpy
#   Downloading earthpy-0.9.4-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from earthpy) (1.0.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from earthpy) (3.10.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from earthpy) (1.26.4)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (from earthpy) (1.4.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from earthpy) (0.25.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from earthpy) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (2.8.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (0.10.0)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (2.0.7)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (25.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->earthpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->earthpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->earthpy) (2.3.0)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (0.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas->earthpy) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas->earthpy) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->earthpy) (1.17.0)
# Downloading earthpy-0.9.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.0 MB/s eta 0:00:00
# Installing collected packages: earthpy
# Successfully installed earthpy-0.9.4

# %%
# Import packages
import pandas as pd
import numpy as np
import keras
from keras import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Dropout, Flatten, Input, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping
from keras import Model
import rasterio
import earthpy.plot as ep
from keras.utils import to_categorical, plot_model, model_to_dot
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors

# %%
# Mount GDRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Parameter
FEATURES = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'EVI', 'NBR', 'NDMI', 'NDWI', 'NDBI', 'NDBaI', 'elevation']
LABEL = ['classvalue']
SPLIT = ['sample']
N_CLASSES = 9
CLASSES = [1, 2, 3, 4, 5, 6, 7, 8, 9]
PALETTE = ['#F08080', '#D2B48C', '#87CEFA', '#008080', '#90EE90', '#228B22', '#808000', '#FF8C00', '#006400']
SAMPLE_PATH = '/content/drive/MyDrive/DL/Samples_LC_Jambi_2023.csv'
IMAGE_PATH = '/content/drive/MyDrive/DL/Landsat_Jambi_2023.tif'

# %%
# Load image
image = rasterio.open(IMAGE_PATH)
bandNum = image.count
height = image.height
width = image.width
crs = image.crs
transform = image.transform
shape = (height, width)

image_vis = []
for x in [6, 5, 4]:
  image_vis.append(image.read(x))
image_vis = np.stack(image_vis)

plot_size = (8, 8)
ep.plot_rgb(
  image_vis,
  figsize=plot_size,
  stretch=True,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/earthpy/spatial.py:561: RuntimeWarning: invalid value encountered in cast
#   return (bytedata.clip(low, high) + 0.5).astype("uint8")
# <Axes: >

# %%
# Read sample
samples = pd.read_csv(SAMPLE_PATH)
samples = samples.sample(frac = 1) # Shuffle data
samples
# Out:
#              B1        B2        B3        B4        B5        B6        B7  \
# 8712   0.018694  0.024895  0.058761  0.034932  0.380003  0.190500  0.077296
# 352    0.060013  0.076237  0.115452  0.117900  0.229027  0.203068  0.145042
# 13294  0.020165  0.024400  0.060343  0.036885  0.262522  0.138552  0.062102
# 4719   0.068441  0.084309  0.138415  0.161309  0.225590  0.236081  0.186719
# 13252  0.019615  0.023547  0.052972  0.037297  0.247617  0.132530  0.062735
# ...         ...       ...       ...       ...       ...       ...       ...
# 83     0.071012  0.084735  0.118477  0.129202  0.204690  0.254437  0.219760
# 10947  0.016246  0.021389  0.054155  0.031399  0.360450  0.151656  0.056025
# 3383   0.074148  0.088530  0.148439  0.177657  0.194928  0.138635  0.090249
# 15048  0.022475  0.029597  0.060783  0.039827  0.306248  0.197375  0.085065
# 3025   0.042811  0.056396  0.107051  0.092091  0.084267  0.034520  0.023712
#
#             EVI       NBR      NDMI      NDWI      NDBI     NDBaI  elevation  \
# 8712   0.614929  0.661944  0.332168 -0.732151 -0.332168  0.422723         54
# 352    0.203583  0.224517  0.060079 -0.329700 -0.060079  0.166686         11
# 13294  0.433641  0.617389  0.309094 -0.626206 -0.309094  0.381002          9
# 4719   0.102940  0.094277 -0.022725 -0.239488  0.022725  0.116751         11
# 13252  0.406087  0.595718  0.302744 -0.647543 -0.302744  0.357437          8
# ...         ...       ...       ...       ...       ...       ...        ...
# 83     0.140375 -0.035505 -0.108352 -0.266773  0.108352  0.073129         13
# 10947  0.592489  0.730956  0.407716 -0.738763 -0.407716  0.460471          7
# 3383   0.027037  0.367067  0.168761 -0.135391 -0.168761  0.211401         11
# 15048  0.503351  0.565232  0.216179 -0.668787 -0.216179  0.397642         27
# 3025  -0.016114  0.560798  0.418794  0.119088 -0.418794  0.185592          6
#
#        classvalue sample
# 8712            6  train
# 352             1  train
# 13294           7   test
# 4719            4  train
# 13252           7   test
# ...           ...    ...
# 83              1  train
# 10947           7  train
# 3383            3  train
# 15048           8  train
# 3025            3  train
#
# [18896 rows x 16 columns]

# %%
# Split into train and test based on column
train = samples[samples['sample'] == 'train']
test = samples[samples['sample'] == 'test']

# Split between features and label
train_features = train[FEATURES]
train_label = train[LABEL]
test_features = test[FEATURES]
test_label = test[LABEL]

# Function to reshape array input
def reshape_input(array):
  shape = array.shape
  return array.reshape(shape[0], shape[1], 1)

# Convert samples dataframe (pandas) to numpy array
train_input = reshape_input(train_features.to_numpy())
test_input = reshape_input(test_features.to_numpy())

# Also make label data to categorical
train_output = to_categorical(train_label.to_numpy(), N_CLASSES + 1)
test_output = to_categorical(test_label.to_numpy(), N_CLASSES + 1)

# Show the data shape
print(f'Train features: {train_input.shape}\nTest features: {test_input.shape}\nTrain label: {train_output.shape}\nTest label: {test_output.shape}')
# Out:
# Train features: (14853, 14, 1)
# Test features: (4043, 14, 1)
# Train label: (14853, 10)
# Test label: (4043, 10)

# %%
# Make model for our data
# Input shape
train_shape = train_input.shape
input_shape = (train_shape[1], train_shape[2])

# Model parameter
neuron = 64
drop = 0.2
kernel = 2
pool = 2

# Make sequential model
model = Sequential([
  Input(input_shape),
  Conv1D(neuron * 1, kernel, activation='relu'),
  Conv1D(neuron * 1, kernel, activation='relu'),
  MaxPooling1D(pool),
  Dropout(drop),
  Conv1D(neuron * 2, kernel, activation='relu'),
  Conv1D(neuron * 2, kernel, activation='relu'),
  MaxPooling1D(pool),
  Dropout(drop),
  GlobalMaxPooling1D(),
  Dense(neuron * 2, activation='relu'),
  Dropout(drop),
  Dense(neuron * 1, activation='relu'),
  Dropout(drop),
  Dense(N_CLASSES + 1, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 13, 64)              │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 12, 64)              │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 6, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 6, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 5, 128)              │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 4, 128)              │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 2, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 2, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d                 │ (None, 128)                 │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 83,274 (325.29 KB)
#  Trainable params: 83,274 (325.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model

# Compline the model
model.compile(
    optimizer='Adam',
    loss='CategoricalCrossentropy',
    metrics=['accuracy']
)

# Create callback to stop training if loss not decreasing
stop = EarlyStopping(
    monitor='loss',
    patience=5
)

# Fit the model
result = model.fit(
    x=train_input, y=train_output,
    validation_data=(test_input, test_output),
    batch_size=1024,
    callbacks=[stop],
    epochs=100,
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.1697 - loss: 2.2131 - val_accuracy: 0.1202 - val_loss: 2.1597
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.2117 - loss: 2.0201 - val_accuracy: 0.2889 - val_loss: 1.9341
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.2510 - loss: 1.8261 - val_accuracy: 0.3866 - val_loss: 1.7048
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3496 - loss: 1.6427 - val_accuracy: 0.5009 - val_loss: 1.4555
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.4518 - loss: 1.4049 - val_accuracy: 0.6668 - val_loss: 1.1754
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.5502 - loss: 1.1832 - val_accuracy: 0.6317 - val_loss: 1.0496
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.6347 - loss: 1.0060 - val_accuracy: 0.6404 - val_loss: 0.9569
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.6655 - loss: 0.9059 - val_accuracy: 0.6597 - val_loss: 0.9115
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6912 - loss: 0.8405 - val_accuracy: 0.6866 - val_loss: 0.9056
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7112 - loss: 0.7804 - val_accuracy: 0.7049 - val_loss: 0.8537
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7334 - loss: 0.7342 - val_accuracy: 0.7420 - val_loss: 0.7837
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.7446 - loss: 0.7150 - val_accuracy: 0.7255 - val_loss: 0.8335
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7549 - loss: 0.6830 - val_accuracy: 0.7529 - val_loss: 0.7478
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.7628 - loss: 0.6542 - val_accuracy: 0.7569 - val_loss: 0.7462
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7652 - loss: 0.6423 - val_accuracy: 0.7554 - val_loss: 0.7678
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7825 - loss: 0.6134 - val_accuracy: 0.7677 - val_loss: 0.7371
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7840 - loss: 0.6139 - val_accuracy: 0.7435 - val_loss: 0.7706
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.7874 - loss: 0.6100 - val_accuracy: 0.7702 - val_loss: 0.7178
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.7838 - loss: 0.6003 - val_accuracy: 0.7759 - val_loss: 0.6835
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.8008 - loss: 0.5716 - val_accuracy: 0.7727 - val_loss: 0.7387
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7940 - loss: 0.5730 - val_accuracy: 0.7611 - val_loss: 0.6715
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8031 - loss: 0.5611 - val_accuracy: 0.7685 - val_loss: 0.7407
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.8041 - loss: 0.5523 - val_accuracy: 0.7398 - val_loss: 0.7456
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - accuracy: 0.8038 - loss: 0.5487 - val_accuracy: 0.7492 - val_loss: 0.7130
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8060 - loss: 0.5354 - val_accuracy: 0.7309 - val_loss: 0.6901
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8100 - loss: 0.5371 - val_accuracy: 0.7690 - val_loss: 0.7131
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8135 - loss: 0.5280 - val_accuracy: 0.7514 - val_loss: 0.7313
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.8158 - loss: 0.5206 - val_accuracy: 0.7833 - val_loss: 0.6657
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.8199 - loss: 0.5091 - val_accuracy: 0.7710 - val_loss: 0.6923
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8186 - loss: 0.5080 - val_accuracy: 0.7353 - val_loss: 0.7180
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8246 - loss: 0.4979 - val_accuracy: 0.7524 - val_loss: 0.7558
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8241 - loss: 0.4960 - val_accuracy: 0.7618 - val_loss: 0.6569
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.8232 - loss: 0.4814 - val_accuracy: 0.7536 - val_loss: 0.7207
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8256 - loss: 0.4824 - val_accuracy: 0.7685 - val_loss: 0.6511
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8275 - loss: 0.4797 - val_accuracy: 0.7569 - val_loss: 0.7684
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8312 - loss: 0.4678 - val_accuracy: 0.7762 - val_loss: 0.6779
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.8336 - loss: 0.4699 - val_accuracy: 0.7710 - val_loss: 0.6613
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8346 - loss: 0.4610 - val_accuracy: 0.7903 - val_loss: 0.6600
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - accuracy: 0.8425 - loss: 0.4469 - val_accuracy: 0.7623 - val_loss: 0.6625
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8458 - loss: 0.4450 - val_accuracy: 0.7527 - val_loss: 0.7770
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8417 - loss: 0.4433 - val_accuracy: 0.7583 - val_loss: 0.7157
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8420 - loss: 0.4484 - val_accuracy: 0.7574 - val_loss: 0.7743
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.8418 - loss: 0.4427 - val_accuracy: 0.7353 - val_loss: 0.6951
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.8428 - loss: 0.4378 - val_accuracy: 0.7843 - val_loss: 0.6994
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.8433 - loss: 0.4392 - val_accuracy: 0.7665 - val_loss: 0.7322
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8543 - loss: 0.4126 - val_accuracy: 0.7628 - val_loss: 0.6646
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.8495 - loss: 0.4181 - val_accuracy: 0.7722 - val_loss: 0.6727
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.8512 - loss: 0.4101 - val_accuracy: 0.7762 - val_loss: 0.7374
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - accuracy: 0.8534 - loss: 0.4161 - val_accuracy: 0.7789 - val_loss: 0.6969
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.8538 - loss: 0.4140 - val_accuracy: 0.7742 - val_loss: 0.7621
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8551 - loss: 0.4073 - val_accuracy: 0.7727 - val_loss: 0.7353
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.8542 - loss: 0.4083 - val_accuracy: 0.7801 - val_loss: 0.7155
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.8556 - loss: 0.4019 - val_accuracy: 0.7576 - val_loss: 0.7855
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8564 - loss: 0.4023 - val_accuracy: 0.7702 - val_loss: 0.6683
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8520 - loss: 0.4039 - val_accuracy: 0.7658 - val_loss: 0.7249
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.8596 - loss: 0.3991 - val_accuracy: 0.7925 - val_loss: 0.6444
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8626 - loss: 0.3832 - val_accuracy: 0.7954 - val_loss: 0.6901
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.8633 - loss: 0.3825 - val_accuracy: 0.7697 - val_loss: 0.7150
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.8678 - loss: 0.3730 - val_accuracy: 0.7858 - val_loss: 0.7223
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8669 - loss: 0.3843 - val_accuracy: 0.7841 - val_loss: 0.7458
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8649 - loss: 0.3734 - val_accuracy: 0.7806 - val_loss: 0.7100
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8636 - loss: 0.3800 - val_accuracy: 0.7945 - val_loss: 0.7185
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8666 - loss: 0.3663 - val_accuracy: 0.8014 - val_loss: 0.6863
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8719 - loss: 0.3646 - val_accuracy: 0.7858 - val_loss: 0.7535
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8697 - loss: 0.3661 - val_accuracy: 0.7707 - val_loss: 0.7941
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8701 - loss: 0.3736 - val_accuracy: 0.7648 - val_loss: 0.8270
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8702 - loss: 0.3597 - val_accuracy: 0.8048 - val_loss: 0.6933
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.8663 - loss: 0.3635 - val_accuracy: 0.7776 - val_loss: 0.7559
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8699 - loss: 0.3650 - val_accuracy: 0.7799 - val_loss: 0.8049
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8719 - loss: 0.3537 - val_accuracy: 0.7865 - val_loss: 0.7331
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.8717 - loss: 0.3555 - val_accuracy: 0.7935 - val_loss: 0.7285
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8732 - loss: 0.3522 - val_accuracy: 0.8014 - val_loss: 0.6681
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.8728 - loss: 0.3462 - val_accuracy: 0.7796 - val_loss: 0.7523
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.8810 - loss: 0.3329 - val_accuracy: 0.7791 - val_loss: 0.7626
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8793 - loss: 0.3388 - val_accuracy: 0.7744 - val_loss: 0.8115
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8738 - loss: 0.3523 - val_accuracy: 0.7930 - val_loss: 0.7337
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.8712 - loss: 0.3511 - val_accuracy: 0.7863 - val_loss: 0.7346
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.8686 - loss: 0.3563 - val_accuracy: 0.7932 - val_loss: 0.7437
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.8786 - loss: 0.3438 - val_accuracy: 0.8031 - val_loss: 0.7256

# %%
# Show history
history = pd.DataFrame(result.history)

plt.figure(figsize = (10, 8))
plt.plot(range(len(history['accuracy'].values.tolist())), history['accuracy'].values.tolist(), label = 'Train_Accuracy')
plt.plot(range(len(history['loss'].values.tolist())), history['loss'].values.tolist(), label = 'Train_Loss')
plt.plot(range(len(history['val_accuracy'].values.tolist())), history['val_accuracy'].values.tolist(), label = 'Test_Accuracy')
plt.plot(range(len(history['val_loss'].values.tolist())), history['val_loss'].values.tolist(), label = 'Test_Loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Predict test data
prediction = np.argmax(model.predict(test_input), 1).flatten()
label = np.argmax(test_output, 1).flatten()

# Confusion matrix
cm = confusion_matrix(label, prediction, normalize='true')
cm = ConfusionMatrixDisplay(cm)
cm.plot()

# Classification report
print(classification_report(label, prediction))
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#               precision    recall  f1-score   support
#
#            1       0.98      0.91      0.95       247
#            2       0.72      0.70      0.71       392
#            3       1.00      0.72      0.83       353
#            4       0.44      0.88      0.58       293
#            5       0.91      0.71      0.80       398
#            6       0.84      0.75      0.79       678
#            7       0.88      0.85      0.87       792
#            8       0.81      0.80      0.80       605
#            9       0.93      1.00      0.96       285
#
#     accuracy                           0.80      4043
#    macro avg       0.83      0.81      0.81      4043
# weighted avg       0.84      0.80      0.81      4043

# %%
# Predict image using the model
image_input = []
for x in range(14):
  image_input.append(image.read(x + 1))
image_input = reshape_input(np.stack(image_input).reshape(14, -1).T)

# Predict
prediction = model.predict(image_input, batch_size=4096*20)
prediction = np.argmax(prediction, 1)
prediction = prediction.reshape(shape[0], shape[1])

# Visualize
cmap, norm = from_levels_and_colors(CLASSES, PALETTE, extend='max')
ep.plot_bands(prediction, cmap=cmap, norm=norm, figsize=plot_size)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step
# <Axes: >

# %%
# Save file to drive
save_location = '/content/drive/MyDrive/DL/'
name = 'LC_Jambi_2023.tif'
location = save_location + name

new_dataset = rasterio.open(
      location,
      mode='w', driver='GTiff',
      height = prediction.shape[0], width = prediction.shape[1],
      count=1, dtype=str(prediction.dtype),
      crs=crs,
      transform=transform
)
new_dataset.write(prediction, 1);
new_dataset.close()
