# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushclin/iac-compettion/blob/main/My_First_Remote_Sensing_with_EE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee

ee.Authenticate()

ee.Initialize(project="projet-iac")

roi = ee.Geometry.Polygon(
    [[[-122.27, 37.87],
      [-122.21, 37.87],
      [-122.21, 37.82],
      [-122.27, 37.82],
      [-122.27, 37.87]]])

start_date = '2023-01-01'
end_date = '2023-12-31'

soil_moisture_dataset = ee.ImageCollection('NASA_USDA/HSL/SMAP10KM_soil_moisture') \
    .filterDate(start_date, end_date) \
    .filterBounds(roi)

def compute_mean_soil_moisture(image):
    return image.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=roi,
        scale=1000  # Adjust scale as needed
    ).get('ssm') # Replace with the correct band name if different

soil_moisture_values = soil_moisture_dataset.map(compute_mean_soil_moisture).getInfo()

soil_moisture_values
# Out:
# /usr/local/lib/python3.11/dist-packages/ee/deprecation.py:207: DeprecationWarning:
#
# Attention required for NASA_USDA/HSL/SMAP10KM_soil_moisture! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/NASA_USDA_HSL_SMAP10KM_soil_moisture
#
#   warnings.warn(warning, category=DeprecationWarning)
# {'type': 'FeatureCollection',
#  'columns': {},
#  'version': 1685085760847782,
#  'id': 'NASA_USDA/HSL/SMAP10KM_soil_moisture',
#  'properties': {'date_range': [1427846400000, 1654473600000],
#   'period': 0,
#   'type_name': 'ImageCollection',
#   'max_mirrored_version': 1659795998347534,
#   'keywords': ['geophysical',
#    'hsl',
#    'moisture',
#    'nasa',
#    'smap',
#    'soil',
#    'usda'],
#   'thumb': 'https://mw1.google.com/ges/dd/images/NASA_USDA_HSL_soil_moisture_thumb.png',
#   'description': '<p>The NASA-USDA Enhanced SMAP Global soil moisture data provides soil moisture information across\nthe globe at 10-km spatial resolution. This dataset includes:\n<a href="ftp://gimms.gsfc.nasa.gov/SMOS/SMAP/Surface_Soil_Moisture_SMAP.pdf">surface</a>\nand <a href="ftp://gimms.gsfc.nasa.gov/SMOS/SMAP/Sub_SurfaceSoil_Moisture_SMAP.pdf">subsurface</a>\nsoil moisture (mm),\n<a href="ftp://gimms.gsfc.nasa.gov/SMOS/SMAP/SoilMoisture_Profile_SMAP.pdf">soil moisture profile</a> (%),\nsurface and subsurface soil moisture anomalies (-).</p><p>The dataset is generated by integrating satellite-derived Soil Moisture Active Passive (SMAP)\nLevel 3 soil moisture observations into the modified two-layer Palmer model using a 1-D\nEnsemble Kalman Filter (EnKF) data assimilation approach.\nSoil moisture anomalies were computed from the climatology of the day of interest.\nThe climatology was estimated based on the full data record of the SMAP satellite observation\nand the 31-day-centered moving-window approach. The assimilation of the SMAP soil moisture\nobservations help improve the model-based soil moisture predictions particularly over poorly\ninstrumented areas of the world that lack good quality precipitation data.</p><p>This dataset was developed by the Hydrological Science Laboratory at NASA&#39;s Goddard Space\nFlight Center in cooperation with USDA Foreign Agricultural Services and USDA Hydrology\nand Remote Sensing Lab.</p><p><b>Provider: <a href="https://gimms.gsfc.nasa.gov/SMOS/SMAP/">NASA GSFC</a></b><br><p><b>Resolution</b><br>10000 meters\n</p><p><b>Cadence</b><br>\n  3 days\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Description</th></tr><tr><td>ssm</td><td><p>Surface soil moisture</p></td></tr><tr><td>susm</td><td><p>Subsurface soil moisture</p></td></tr><tr><td>smp</td><td><p>Soil moisture profile</p></td></tr><tr><td>ssma</td><td><p>Surface soil moisture anomaly</p></td></tr><tr><td>susma</td><td><p>Subsurface soil moisture anomaly</p></td></tr></table><p><b>Terms of Use</b><br><p>This dataset is in the public domain and is available\nwithout restriction on use and distribution. See <a href="https://science.nasa.gov/earth-science/earth-science-data/data-information-policy">NASA&#39;s\nEarth Science Data &amp; Information Policy</a>\nfor additional information.</p><p><b>Suggested citation(s)</b><ul><li><p><strong>Mladenova, I.E., Bolten, J.D., Crow, W., Sazib, N. and Reynolds, C., 2020.</strong>\nAgricultural drought monitoring via the assimilation of SMAP soil moisture retrievals into a\nglobal soil water balance model. <em>Front. Big Data</em>,\n3(10).\n<a href="https://doi.org/10.3389/fdata.2020.00010">doi:10.3389/fdata.2020.00010</a><a href="https://www.frontiersin.org/article/10.3389/fdata.2020.00010">Article</a></p></li><li><p><strong>Mladenova, I.E., Bolten, J.D., Crow, W.T., Sazib, N., Cosh, M.H., Tucker, C.J. and Reynolds,\nC., 2019.</strong>\nEvaluating the operational application of SMAP for global agricultural drought monitoring.\n<em>IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing</em>,\n12(9): 3387-3397.\n<a href="https://doi.org/10.1109/JSTARS.2019.2923555">doi:10.1109/JSTARS.2019.2923555</a><a href="https://ieeexplore.ieee.org/document/8758314">Article</a></p></li><li><p><strong>Sazib, N., Mladenova, I., &amp; Bolten, J. (2020).</strong>\nAssessing the Impact of ENSO on Agriculture over Africa using Earth Observation Data.\n<em>Frontiers in Sustainable Food Systems</em>, 4, 188.\n<a href="https://doi.org/10.3389/fsufs.2020.509914">doi:10.3389/fsufs.2020.509914</a><a href="https://www.frontiersin.org/articles/10.3389/fsufs.2020.509914/full">Article</a><a href="https://scholar.google.com/scholar?cluster=10102210156681705582&amp;oi=scholarr">Google Scholar</a></p></li><li><p><strong>Sazib, N., Mladenova, I. and Bolten, J., 2018.</strong>\nLeveraging the google earth engine for drought assessment using global soil moisture ...
#   'source_tags': ['nasa', 'usda', 'hsl', 'smap'],
#   'visualization_0_max': '28.0',
#   'provider_url': 'https://gimms.gsfc.nasa.gov/SMOS/SMAP/',
#   'title': 'NASA-USDA Enhanced SMAP Global Soil Moisture Data',
#   'sample': 'https://mw1.google.com/ges/dd/images/NASA_USDA_HSL_soil_moisture_sample.png',
#   'tags': ['geophysical', 'hsl', 'moisture', 'nasa', 'smap', 'soil', 'usda'],
#   'product_tags': ['geophysical', 'soil', 'moisture'],
#   'visualization_0_palette': '0300ff,418504,efff07,efff07,ff0303',
#   'provider': 'NASA GSFC',
#   'visualization_0_min': '0.0',
#   'visualization_0_name': 'Soil Moisture',
#   'visualization_0_bands': 'ssm'},
#  'features': []}

# %% [markdown]
# **Explore Landsat Images**

# %%
lat =  39.444012
lon = -121.833619

poi = ee.Geometry.Point(lon,lat)

start_date = '2018-10-01'
end_date = '2019-01-31'

# %%
# get the satellite data
landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")\
            .filterBounds(poi)\
            .filterDate(start_date,end_date)

# %%
# how many images did we get?
print('Total number:', landsat.size().getInfo())
# Out:
# Total number: 8

# %%
# information about the first image in our collection
landsat.first().getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'SR_B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'SR_QA_AEROSOL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_B10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_ATRAN',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_CDIST',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_DRAD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_EMIS',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_EMSD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_QA',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_TRAD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'ST_URAD',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': -32768,
#     'max': 32767},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'QA_PIXEL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]},
#   {'id': 'QA_RADSAT',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7661, 7791],
#    'crs': 'EPSG:32610',
#    'crs_transform': [30, 0, 500385, 0, -30, 4423215]}],
#  'version': 1629895720593702,
#  'id': 'LANDSAT/LC08/C02/T1_L2/LC08_044033_20181007',
#  'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000',
#   'WRS_TYPE': 2,
#   'REFLECTANCE_ADD_BAND_1': -0.2,
#   'REFLECTANCE_ADD_BAND_2': -0.2,
#   'DATUM': 'WGS84',
#   'REFLECTANCE_ADD_BAND_3': -0.2,
#   'REFLECTANCE_ADD_BAND_4': -0.2,
#   'REFLECTANCE_ADD_BAND_5': -0.2,
#   'REFLECTANCE_ADD_BAND_6': -0.2,
#   'REFLECTANCE_ADD_BAND_7': -0.2,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[-120.96945987441705, 37.85396978622024],
#     [-120.91758272903665, 37.84360095586152],
#     [-120.91091374989027, 37.84230108097053],
#     [-120.91032102754652, 37.84319081260253],
#     [-120.90026375188283, 37.87485737375912],
#     [-120.88601930375758, 37.91975025888466],
#     [-120.87475935368046, 37.95523294042605],
#     [-120.76830993328551, 38.28982473972092],
#     [-120.60616669159636, 38.7956184110626],
#     [-120.46920219411804, 39.21870028030481],
#     [-120.35829507594683, 39.55929948514903],
#     [-120.358940626908, 39.55982942717467],
#     [-120.3773619745756, 39.563471697339374],
#     [-121.13362575572384, 39.70944332250483],
#     [-122.47094597878574, 39.95415252966201],
#     [-122.47146231484521, 39.953369391342086],
#     [-122.47255137997769, 39.95009912185038],
#     [-122.97579676306593, 38.235899800160965],
#     [-122.97515026884432, 38.23538966186662],
#     [-122.83153924692401, 38.209342252115945],
#     [-120.96945987441705, 37.85396978622024]]},
#   'REFLECTIVE_SAMPLES': 7661,
#   'GROUND_CONTROL_POINTS_VERSION': 5,
#   'SUN_AZIMUTH': 156.37136574,
#   'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#   'UTM_ZONE': 10,
#   'DATE_ACQUIRED': '2018-10-07',
#   'ELLIPSOID': 'WGS84',
#   'system:time_end': 1538937928212,
#   'DATA_SOURCE_PRESSURE': 'Calculated',
#   'LANDSAT_PRODUCT_ID': 'LC08_L2SP_044033_20181007_20200830_02_T1',
#   'STATION_ID': 'LGN',
#   'TEMPERATURE_ADD_BAND_ST_B10': 149,
#   'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT',
#   'REFLECTANCE_MULT_BAND_7': 2.75e-05,
#   'system:time_start': 1538937928212,
#   'REFLECTANCE_MULT_BAND_6': 2.75e-05,
#   'L1_PROCESSING_LEVEL': 'L1TP',
#   'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#   'L1_DATE_PRODUCT_GENERATED': '2020-08-30T22:04:06Z',
#   'ORIENTATION': 'NORTH_UP',
#   'REFLECTANCE_MULT_BAND_1': 2.75e-05,
#   'WRS_ROW': 33,
#   'REFLECTANCE_MULT_BAND_3': 2.75e-05,
#   'REFLECTANCE_MULT_BAND_2': 2.75e-05,
#   'TARGET_WRS_ROW': 33,
#   'REFLECTANCE_MULT_BAND_5': 2.75e-05,
#   'REFLECTANCE_MULT_BAND_4': 2.75e-05,
#   'THERMAL_LINES': 7791,
#   'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#   'GRID_CELL_SIZE_THERMAL': 30,
#   'IMAGE_QUALITY_TIRS': 9,
#   'TRUNCATION_OLI': 'UPPER',
#   'NADIR_OFFNADIR': 'NADIR',
#   'CLOUD_COVER': 0.05,
#   'REQUEST_ID': 'L2',
#   'EARTH_SUN_DISTANCE': 0.9993983,
#   'GEOMETRIC_RMSE_VERIFY': 3.028,
#   'TIRS_SSM_MODEL': 'FINAL',
#   'COLLECTION_CATEGORY': 'T1',
#   'SCENE_CENTER_TIME': '18:45:28.2127380Z',
#   'GRID_CELL_SIZE_REFLECTIVE': 30,
#   'SUN_ELEVATION': 42.62885674,
#   'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0',
#   'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941,
#   'CLOUD_COVER_LAND': 0.05,
#   'GEOMETRIC_RMSE_MODEL': 5.915,
#   'ROLL_ANGLE': -0.001,
#   'COLLECTION_NUMBER': 2,
#   'DATE_PRODUCT_GENERATED': 1598825983000,
#   'L1_REQUEST_ID': 'L2',
#   'DATA_SOURCE_OZONE': 'MODIS',
#   'SATURATION_BAND_1': 'Y',
#   'DATA_SOURCE_WATER_VAPOR': 'MODIS',
#   'SATURATION_BAND_2': 'Y',
#   'SATURATION_BAND_3': 'Y',
#   'IMAGE_QUALITY_OLI': 9,
#   'SATURATION_BAND_4': 'Y',
#   'LANDSAT_SCENE_ID': 'LC80440332018280LGN00',
#   'SATURATION_BAND_5': 'Y',
#   'MAP_PROJECTION': 'UTM',
#   'SATURATION_BAND_6': 'Y',
#   'SENSOR_ID': 'OLI_TIRS',
#   'SATURATION_BAND_7': 'Y',
#   'SATURATION_BAND_8': 'N',
#   'WRS_PATH': 44,
#   'SATURATION_BAND_9': 'N',
#   'TARGET_WRS_PATH': 44,
#   'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c',
#   'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802,
#   'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_044033_20181007_20200830_02_T1',
#   'PROCESSING_LEVEL': 'L2SP',
#   'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0',
#   'GROUND_CONTROL_POINTS_MODEL': 1318,
#   'SPACECRAFT_ID': 'LANDSAT_8',
#   'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418,
#   'GEOMETRIC_RMSE_MODEL_Y': 4.945,
#   'REFLECTIVE_LINES': 7791,
#   'GEOMETRIC_RMSE_MODEL_X': 3.246,
#   'THERMAL_SAMPLES': 7661,
#   'system:asset_size': 965138511,
#   'DATA_SOURCE_AIR_TEMPERATURE': 'MODIS',
#   'GROUND_CONTROL_POINTS_VERIFY': 416,
#   'system:index': 'LC08_044033_20181007'}}

# %%
# what about cloud cover of our first image?
landsat.first().get('CLOUD_COVER').getInfo()
# Out:
# 0.05

# %%
# when was this image taken?
landsat.first().get('DATE_ACQUIRED').getInfo()
# Out:
# '2018-10-07'

# %%
# what bands did we get?
landsat.first().bandNames().getInfo()
# Out:
# ['SR_B1',
#  'SR_B2',
#  'SR_B3',
#  'SR_B4',
#  'SR_B5',
#  'SR_B6',
#  'SR_B7',
#  'SR_QA_AEROSOL',
#  'ST_B10',
#  'ST_ATRAN',
#  'ST_CDIST',
#  'ST_DRAD',
#  'ST_EMIS',
#  'ST_EMSD',
#  'ST_QA',
#  'ST_TRAD',
#  'ST_URAD',
#  'QA_PIXEL',
#  'QA_RADSAT']

# %%
# put the images in a list
landsat_list = landsat.toList(landsat.size());

# %%
# set some parameters for the images
parameters = {
                'min': 7000,
                'max': 16000,
                'dimensions': 800, # square size in pixels
                'bands': ['SR_B4', 'SR_B3', 'SR_B2'] # bands to display (r,g,b)
             }

# %%
# allow images to display in the notebook
from IPython.display import Image

# the regulars
import pandas as pd
import geopandas as gpd

# earth engine
import ee

# %%
# create an empty data container
data = []

for i in range(landsat.size().getInfo()):

    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()

    cloud = ee.Image(landsat_list.get(i)).get('CLOUD_COVER').getInfo()

    # print the image info
    print('Image #',i,date,'Cloud cover:',cloud)

    # display the image
    display(Image(url = ee.Image(landsat_list.get(i)).getThumbUrl(parameters)))

    # data to list
    this_data = [i,date,cloud]

    # append the data
    data.append(this_data)


# Create the pandas DataFrame
df = pd.DataFrame(data, columns = ['Image #', 'Date', 'Cloud Cover'])
# Out:
# Image # 0 2018-10-07 Cloud cover: 0.05
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/7da7c823ee9999f65001f9018a59a7c2-84fb35d054b22164661a56a4f6dae686:getPixels"/>
# Image # 1 2018-10-23 Cloud cover: 73.04
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/26e900f7e4dce87aeeb9483b2b999917-e1d571e9a581c534a3ebd29c54723822:getPixels"/>
# Image # 2 2018-11-08 Cloud cover: 11.83
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/f4b3e1ae33a7768e89f3861acc10c44e-c2035a91127e3dd275aaa8a3647eb187:getPixels"/>
# Image # 3 2018-11-24 Cloud cover: 67.16
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/90277ef611d466d64659ccad1e2b5757-62dbb8aba58a70c65062e2d1b20a508c:getPixels"/>
# Image # 4 2018-12-10 Cloud cover: 56.09
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/42ec14e96074292e10178585bba9dd7a-e9c3cc638052a5361cedc2df61450875:getPixels"/>
# Image # 5 2018-12-26 Cloud cover: 5.99
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/83671316f0d59462cd0dc9e2292e003a-670fd3ccd5c8ea5ae901b9fe6adb45b8:getPixels"/>
# Image # 6 2019-01-11 Cloud cover: 80.06
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/a5889a55f52d16e213d9ff4769bd91c5-f9dd9676681d2e8263f4b9fd660d876f:getPixels"/>
# Image # 7 2019-01-27 Cloud cover: 5.21
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/1e509a288b639701a3c32045bc5b0083-75e577cdee4abed56e76f0004bafdcc8:getPixels"/>

# %%
df
# Out:
#    Image #        Date  Cloud Cover
# 0        0  2018-10-07         0.05
# 1        1  2018-10-23        73.04
# 2        2  2018-11-08        11.83
# 3        3  2018-11-24        67.16
# 4        4  2018-12-10        56.09
# 5        5  2018-12-26         5.99
# 6        6  2019-01-11        80.06
# 7        7  2019-01-27         5.21

# %%
# ndvi palette: red is low, green is high vegetation
palette = ['red', 'yellow', 'green']

ndvi_parameters = {'min': 0,
                   'max': 0.4,
                   'dimensions': 512,
                   'palette': palette,
                   'region': roi}

# %%
# create a list of images we want (before, during, after)
landsat_sequence = [0,2,5]

# %%
# Define a region of interest with a buffer zone of 20 km
roi = poi.buffer(20000) # meters

# %%
parameters = {
                'min': 6000,
                'max': 16000,
                'dimensions': 800,
                'bands': ['SR_B4', 'SR_B3', 'SR_B2'],
                'region':roi
             }

# %%
for i in landsat_sequence:

    # when was this image taken?
    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()

    # cloud cover
    cloud = ee.Image(landsat_list.get(i)).get('CLOUD_COVER').getInfo()

    print('Image #',i,date,'Cloud cover:',cloud)

    display(Image(url = ee.Image(landsat_list.get(i)).getThumbUrl(parameters)))
# Out:
# Image # 0 2018-10-07 Cloud cover: 0.05
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/51d6ce90d1045b96fb16f11bc3fdecb0-0e392d97419fbd10e016eebde5342760:getPixels"/>
# Image # 2 2018-11-08 Cloud cover: 11.83
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/92db8ff1459bb5ee1d61c69be4329d2d-cd39f5de4edfdfd5cd939339c89f3a02:getPixels"/>
# Image # 5 2018-12-26 Cloud cover: 5.99
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/cf28036bf968482f2c6b233883b4d82a-1d14b1cca9b8b8c3ecf5e3d3db43f3e1:getPixels"/>

# %%
# ndvi palette: red is low, green is high vegetation
palette = ['red', 'yellow', 'green']

ndvi_parameters = {'min': 0,
                   'max': 0.4,
                   'dimensions': 512,
                   'palette': palette,
                   'region': roi}

# %%
for i in landsat_sequence:

    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()

    print('Image #',i,date)

    display(Image(url=ee.Image(landsat_list.get(i)).normalizedDifference(['SR_B5', 'SR_B4']).getThumbUrl(ndvi_parameters)))
# Out:
# Image # 0 2018-10-07
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/c7bdfedaca1d504c9904cf489758f0fd-3556fed128b1b2af88529067ea0d4978:getPixels"/>
# Image # 2 2018-11-08
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/5c37d437da707c71714eab56c9be018b-6b65e2afaff825bea7f664df16d15d3c:getPixels"/>
# Image # 5 2018-12-26
# <img src="https://earthengine.googleapis.com/v1/projects/projet-iac/thumbnails/a26f162b56f49bed35207bd5f9e4b33b-6f2f8387eadc8e82d32a252e0ecbe903:getPixels"/>

# %%
# a simple folium map
import folium

m = folium.Map(location=[lat,lon])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6fe738dc314f3e08caade20ad9bf236 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6fe738dc314f3e08caade20ad9bf236&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6fe738dc314f3e08caade20ad9bf236 = L.map(
#                 &quot;map_c6fe738dc314f3e08caade20ad9bf236&quot;,
#                 {
#                     center: [39.444012, -121.833619],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f952fc185993aef90b81a7cc2d933d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f952fc185993aef90b81a7cc2d933d9.addTo(map_c6fe738dc314f3e08caade20ad9bf236);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Google function that allows ee layers on folium
def add_ee_layer(self, ee_image_object, vis_params, name):
    """Adds a method for displaying Earth Engine image tiles to folium map."""
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)

# Add Earth Engine drawing method to folium
folium.Map.add_ee_layer = add_ee_layer

# %%
# Create a map
my_map = folium.Map(location=[lat, lon], zoom_start=10)

# Add a layer for each satellite image of interest (before, during and after)
for i in landsat_sequence:

    # when was this image taken?
    date = ee.Image(landsat_list.get(i)).get('DATE_ACQUIRED').getInfo()

    my_map.add_ee_layer(ee.Image(landsat_list.get(i)).normalizedDifference(['SR_B5', 'SR_B4']),
                        ndvi_parameters,
                        name=date)

# Add a layer control panel to the map
folium.LayerControl(collapsed = False).add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abfbdb166783b1963e1a2f4fecb4e5c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abfbdb166783b1963e1a2f4fecb4e5c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abfbdb166783b1963e1a2f4fecb4e5c5 = L.map(
#                 &quot;map_abfbdb166783b1963e1a2f4fecb4e5c5&quot;,
#                 {
#                     center: [39.444012, -121.833619],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_390d3d09dc99d860892bb24d4c1a48cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_390d3d09dc99d860892bb24d4c1a48cb.addTo(map_abfbdb166783b1963e1a2f4fecb4e5c5);
#
#
#             var tile_layer_c19117186615950e0b39e4ed9eed4935 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/projet-iac/maps/ef7604e801671257066fbfcde4bd7c23-28aafa4c7a35a5cbfa635bf425c65b76/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c19117186615950e0b39e4ed9eed4935.addTo(map_abfbdb166783b1963e1a2f4fecb4e5c5);
#
#
#             var tile_layer_2fe9c2a9e6686e5ee6c8b2e02b703eef = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/projet-iac/maps/a32efabb9cf02bf8b89a2cd7cb839dfa-1deadb65f53ca31cba35684a0705a2f1/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fe9c2a9e6686e5ee6c8b2e02b703eef.addTo(map_abfbdb166783b1963e1a2f4fecb4e5c5);
#
#
#             var tile_layer_3d91cd26138619bf9257b53f8f9f6a71 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/projet-iac/maps/dfe88e4327f0d583f04245eed0b45d1a-b78448df987ce221d4807d5e24d2ee55/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d91cd26138619bf9257b53f8f9f6a71.addTo(map_abfbdb166783b1963e1a2f4fecb4e5c5);
#
#
#             var layer_control_340b016bc3e1f17d5509da44b531680a_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_390d3d09dc99d860892bb24d4c1a48cb,
#                 },
#                 overlays :  {
#                     &quot;2018-10-07&quot; : tile_layer_c19117186615950e0b39e4ed9eed4935,
#                     &quot;2018-11-08&quot; : tile_layer_2fe9c2a9e6686e5ee6c8b2e02b703eef,
#                     &quot;2018-12-26&quot; : tile_layer_3d91cd26138619bf9257b53f8f9f6a71,
#                 },
#             };
#             let layer_control_340b016bc3e1f17d5509da44b531680a = L.control.layers(
#                 layer_control_340b016bc3e1f17d5509da44b531680a_layers.base_layers,
#                 layer_control_340b016bc3e1f17d5509da44b531680a_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_abfbdb166783b1963e1a2f4fecb4e5c5);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map.save('camp.html')
